# %%
import pandas as pd
df = pd.read_csv('churn.csv')
df
# Out:
#                    churn  Customer_Age Gender  ...  Total_Trans_Ct Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
# 0      Existing Customer            45      M  ...              42               1.625                 0.061
# 1      Existing Customer            49      F  ...              33               3.714                 0.105
# 2      Existing Customer            51      M  ...              20               2.333                 0.000
# 3      Existing Customer            40      F  ...              20               2.333                 0.760
# 4      Existing Customer            40      M  ...              28               2.500                 0.000
# ...                  ...           ...    ...  ...             ...                 ...                   ...
# 10122  Existing Customer            50      M  ...             117               0.857                 0.462
# 10123  Attrited Customer            41      M  ...              69               0.683                 0.511
# ...

# %%
df.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  ...  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count  10127.000000     10127.000000    10127.000000  ...    10127.000000         10127.000000           10127.000000
# mean      46.325960         2.346203       35.928409  ...       64.858695             0.712222               0.274894
# std        8.016814         1.298908        7.986416  ...       23.472570             0.238086               0.275691
# min       26.000000         0.000000       13.000000  ...       10.000000             0.000000               0.000000
# 25%       41.000000         1.000000       31.000000  ...       45.000000             0.582000               0.023000
# 50%       46.000000         2.000000       36.000000  ...       67.000000             0.702000               0.176000
# 75%       52.000000         3.000000       40.000000  ...       81.000000             0.818000               0.503000
# ...

# %%
list(df.Customer_Age.sort_values())[int((len(df.Customer_Age)+1)*0.75)]
# Out:
# 52

# %%
temp = df[df.Marital_Status == 'Unknown']
temp
# Out:
#                    churn  Customer_Age Gender  ...  Total_Trans_Ct Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
# 3      Existing Customer            40      F  ...              20               2.333                 0.760
# 7      Existing Customer            32      M  ...              36               0.714                 0.048
# 10     Existing Customer            42      M  ...              42               0.680                 0.217
# 13     Existing Customer            35      M  ...              33               2.000                 0.195
# 15     Existing Customer            44      M  ...              27               1.700                 0.230
# ...                  ...           ...    ...  ...             ...                 ...                   ...
# 10070  Existing Customer            47      M  ...             123               0.836                 0.040
# 10100  Existing Customer            39      M  ...             128               0.684                 0.000
# ...

# %%
df.groupby(by='churn').count()
# Out:
#                    Customer_Age  Gender  Dependent_count  ...  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# churn                                                     ...
# Attrited Customer          1627    1627             1627  ...            1627                 1627                   1627
# Existing Customer          8500    8500             8500  ...            8500                 8500                   8500
#
# [2 rows x 19 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
corr_df = pd.DataFrame()
corr_df['churn'] = le.fit_transform(temp.churn)
corr_df['marital'] = [1] * len(temp.churn)

# %%
import seaborn as sns
sns.heatmap(corr_df.corr(),annot=True)
# Out:
# <Axes: >
