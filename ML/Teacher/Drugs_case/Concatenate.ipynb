# %%
import pandas as pd
# import numpy as np
# import sys
#np.set_printoptions(threshold=sys.maxsize)
df1 = pd.read_csv('./data/drug_reviews.csv')
df1
# Out:
#        uniqueID         drugName                     condition  \
# 0        163740      Mirtazapine                    Depression
# 1        206473       Mesalamine  Crohn's Disease, Maintenance
# 2        159672          Bactrim       Urinary Tract Infection
# 3         39293         Contrave                   Weight Loss
# 4         97768  Cyclafem 1 / 35                 Birth Control
# ...         ...              ...                           ...
# 53761    159999        Tamoxifen     Breast Cancer, Prevention
# 53762    140714     Escitalopram                       Anxiety
# 53763    130945   Levonorgestrel                 Birth Control
# 53764     47656       Tapentadol                          Pain
# 53765    113712        Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# 0      "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# ...

# %%
df2 = pd.read_csv('./data/drugsComTest_raw.csv')
df2
# Out:
#        uniqueID         drugName                     condition  \
# 0        163740      Mirtazapine                    Depression
# 1        206473       Mesalamine  Crohn's Disease, Maintenance
# 2        159672          Bactrim       Urinary Tract Infection
# 3         39293         Contrave                   Weight Loss
# 4         97768  Cyclafem 1 / 35                 Birth Control
# ...         ...              ...                           ...
# 53761    159999        Tamoxifen     Breast Cancer, Prevention
# 53762    140714     Escitalopram                       Anxiety
# 53763    130945   Levonorgestrel                 Birth Control
# 53764     47656       Tapentadol                          Pain
# 53765    113712        Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# 0      "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# ...

# %% [markdown]
# ## drug_reviews.csv и drugsComTest_raw.csv одинаковые

# %%
df_test = pd.read_csv('./data/drugsComTest_raw.csv')
df_train = pd.read_csv('./data/drugsComTrain_raw.csv')

# %%
df_test
# Out:
#        uniqueID         drugName                     condition  \
# 0        163740      Mirtazapine                    Depression
# 1        206473       Mesalamine  Crohn's Disease, Maintenance
# 2        159672          Bactrim       Urinary Tract Infection
# 3         39293         Contrave                   Weight Loss
# 4         97768  Cyclafem 1 / 35                 Birth Control
# ...         ...              ...                           ...
# 53761    159999        Tamoxifen     Breast Cancer, Prevention
# 53762    140714     Escitalopram                       Anxiety
# 53763    130945   Levonorgestrel                 Birth Control
# 53764     47656       Tapentadol                          Pain
# 53765    113712        Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# 0      "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# ...

# %%
df_train
# Out:
#         uniqueID                  drugName                     condition  \
# 0         206461                 Valsartan  Left Ventricular Dysfunction
# 1          95260                Guanfacine                          ADHD
# 2          92703                    Lybrel                 Birth Control
# 3         138000                Ortho Evra                 Birth Control
# 4          35696  Buprenorphine / naloxone             Opiate Dependence
# ...          ...                       ...                           ...
# 161292    191035                   Campral            Alcohol Dependence
# 161293    127085            Metoclopramide               Nausea/Vomiting
# 161294    187382                   Orencia          Rheumatoid Arthritis
# 161295     47128        Thyroid desiccated           Underactive Thyroid
# 161296    215220              Lubiprostone         Constipation, Chronic
#
#                                                    review  rating       date  \
# ...

# %%
for col in df_test.columns:
    print(col)
    print(df_test[col].unique()[:600])
# Out:
# uniqueID
# [163740 206473 159672  39293  97768 208087 215892 169852  23295  71428
#  196802  31947   4907  66736  97013 213376 151674  33173  30401 152490
#  231397  38116 102969  12626 190527 229975 173391  35608 187230 211675
#   79865  27607 207923 156919  77164 101149 178004  60341 141462 133539
#  191095  50229 130301 101371  79569  17957 219567 171525 173027 202002
#  143003  31908   3350 226299 190325 146651  25240   5357  13407  46742
#   11464 124544 229996 131523 209386 229572 105440 201582 158346 159659
#   15423  95748   6971 131683 188604  19559 104580  26989 128575 122089
#  191146 120889 167387 204427  58200 147575 181913 177034 213569 138243
#  107660  34479 129438 102941 167908  56193 159628  58280  38461 128928
#   41991  85618  62652 129850 103401  45260 222701 218886 224062   9723
#  215685 188968 224823 169168 138742  81226 215782 219697 168177  21821
#  189728 108899 224904 135063 225258   6760   9695  44179  65334 225793
# ...

# %%
for col in df_train.columns:
    print(col)
    print(df_train[col].unique()[:600])
# Out:
# uniqueID
# [206461  95260  92703 138000  35696 155963 165907 102654  74811  48928
#   29607  75612 191290 221320  98494  81890  48188 219869 212077 119705
#   12372 231466 227020  41928 213649  51215 206180  78563 132258  27339
#   51452  96233 204999 214453  71188  80520 125343  93678  60678 206444
#  221934  39795 173398  12056 121333 111409 111474 188061 146502 153093
#  156544 135645  69629  96906 215018 102449  60455  87285 225508 106703
#  131704 192806  69488 107449  60156  88659  24139 131909 202903  85162
#   12559  83734 168378 172031 144224 109866 216434   9116 111410  64089
#  217014 171349  60050 131041  17083 186984 202401 189138 156143  56141
#   43085 187720   7337  79467 147133  45237 102810  60280  10677 196244
#   19966 229524 180062 126595 208641 220696 122541 163567  57623 137538
#  156303  34093 116910 166891 160750  65646  61002  49143  58547  35254
#  165013  77567 195482 144777 185739 182130    632 104905  51480  62773
# ...

# %%
df = pd.concat([df_train,df_test])
df
# Out:
#        uniqueID                  drugName                     condition  \
# 0        206461                 Valsartan  Left Ventricular Dysfunction
# 1         95260                Guanfacine                          ADHD
# 2         92703                    Lybrel                 Birth Control
# 3        138000                Ortho Evra                 Birth Control
# 4         35696  Buprenorphine / naloxone             Opiate Dependence
# ...         ...                       ...                           ...
# 53761    159999                 Tamoxifen     Breast Cancer, Prevention
# 53762    140714              Escitalopram                       Anxiety
# 53763    130945            Levonorgestrel                 Birth Control
# 53764     47656                Tapentadol                          Pain
# 53765    113712                 Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# ...

# %%
from sklearn.model_selection import train_test_split
df_tr, df_te = train_test_split(df, test_size=0.5)

# %%
df_tr.loc[df_tr['review'].duplicated(),:]
# Out:
#        uniqueID                  drugName  \
# 29773     29475                Topiramate
# 9373     122549               Linaclotide
# 606       78165                   Zyprexa
# 5494      46168                   Repatha
# 48064    106175             Oxymetazoline
# ...         ...                       ...
# 40146    120463               Montelukast
# 35276    203086         Gildess Fe 1 / 20
# 1786      35701  Buprenorphine / naloxone
# 65836    178347                Duloxetine
# 77825     62405                Citalopram
#
#                                      condition  \
# 29773                          Bipolar Disorde
# 9373                     Constipation, Chronic
# 606                                 Depression
# 5494   High Cholesterol, Familial Heterozygous
# 48064                         Nasal Congestion
# ...                                        ...
# 40146                      Asthma, Maintenance
# 35276                            Birth Control
# ...

# %%
df_tr.loc[df_tr['review'].duplicated(),'review'].iloc[0]
# Out:
# '"I was diagnosed with bipolar depression about a year ago. I have been on topamax for that as well as migraine headaches for 8 to 9ish months now.  The migraines went away, and I have lost about 40 pounds since taking Topamax! The only downfall is hair loss. I highly warn anybody taking this drug not to miss a dose or try weaning yourself off, because I have done both and ended up with very bad mood swings and will be crying on the floor one minute, then raging and angry, then it will be as if nothing happened."'

# %%
df_tr[df_tr['review'] == '"This medicine is great your nose clears up within seconds of using."']
# Out:
#         uniqueID       drugName         condition  \
# 106034    106196  Oxymetazoline  Nasal Congestion
#
#                                                    review  rating       date  \
# 106034  "This medicine is great your nose clears up wi...      10  21-Dec-11
#
#         usefulCount
# 106034            3

# %%
df_te.duplicated()
# Out:
# 62338     False
# 106602    False
# 32882     False
# 4686      False
# 41429     False
#           ...
# 68431     False
# 77322     False
# 142393    False
# 36988     False
# 130175    False
# Length: 107532, dtype: bool

# %%
df1[~df1['date'].isin(df2['date'])]
# Out:
# Empty DataFrame
# Columns: [uniqueID, drugName, condition, review, rating, date, usefulCount]
# Index: []

# %%
df_te[~df_te['review'].isin(df_tr['review'])]
# Out:
#         uniqueID                            drugName  \
# 62338      53936                           Minoxidil
# 32882     197935                          Metoprolol
# 4686      191642                    Lisdexamfetamine
# 41429      31475                          Miconazole
# 50781      64411                          Sertraline
# ...          ...                                 ...
# 18622     108081  Ethinyl estradiol / norelgestromin
# 68431     210221                             Linzess
# 142393     69859                      Insulin aspart
# 36988     106278                            Implanon
# 130175    204938                             Levemir
#
#                            condition  \
# 62338                       Alopecia
# 32882   Supraventricular Tachycardia
# 4686                            ADHD
# 41429        Vaginal Yeast Infection
# 50781       Major Depressive Disorde
# ...                              ...
# 18622                  Birth Control
# ...

# %%
df_tr
# Out:
#         uniqueID                  drugName                  condition  \
# 30147     165296  Phentermine / topiramate                Weight Loss
# 147032    176507                 Lorazepam              Panic Disorde
# 21770       2570                   Camrese              Birth Control
# 27759     159660                   Bactrim    Urinary Tract Infection
# 41893       2182                 Metformin  Polycystic Ovary Syndrome
# ...          ...                       ...                        ...
# 57710     125451                  Dulcolax               Constipation
# 65836     178347                Duloxetine                 Depression
# 139064      3117            Nitrofurantoin          Bladder Infection
# 77825      62405                Citalopram                 Depression
# 107037    224297             Levothyroxine        Underactive Thyroid
#
#                                                    review  rating       date  \
# ...

# %%
df_te.to_csv('./data/test.csv', index=False)
df_tr.to_csv('./data/train.csv', index=False)
