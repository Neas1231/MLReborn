# %%
import pandas as pd
import numpy as np
import random
df = pd.DataFrame([[random.randrange(10000,60000),random.randrange(20,70),random.choice([1,2,3,4,5,6,7,8])] for _ in range(1000)],columns=['Цена','Площадь','Этажи'])
df
# Out:
#       Цена  Площадь  Этажи
# 0    40404       40      7
# 1    14422       52      6
# 2    49991       56      4
# 3    10670       61      1
# 4    11287       62      2
# ..     ...      ...    ...
# 995  18111       46      2
# 996  36388       59      3
# 997  12718       23      5
# 998  53640       29      3
# 999  52207       42      2
#
# [1000 rows x 3 columns]

# %%
X = df.drop(columns=['Цена'])
y = df['Цена']

# %%
X
# Out:
#      Площадь  Этажи
# 0         40      7
# 1         52      6
# 2         56      4
# 3         61      1
# 4         62      2
# ..       ...    ...
# 995       46      2
# 996       59      3
# 997       23      5
# 998       29      3
# 999       42      2
#
# [1000 rows x 2 columns]

# %%
y
# Out:
# 0      40404
# 1      14422
# 2      49991
# 3      10670
# 4      11287
#        ...
# 995    18111
# 996    36388
# 997    12718
# 998    53640
# 999    52207
# Name: Цена, Length: 1000, dtype: int64

# %%
w = [1, 2]
f_x = w*X
f_x
# Out:
#      Площадь  Этажи
# 0         40     14
# 1         52     12
# 2         56      8
# 3         61      2
# 4         62      4
# ..       ...    ...
# 995       46      4
# 996       59      6
# 997       23     10
# 998       29      6
# 999       42      4
#
# [1000 rows x 2 columns]

# %%
w = [1, 2]
X = np.linspace(0, 100, 200).reshape(-1,2)
f_x = w*X
f_x
# Out:
# array([[  0.        ,   1.00502513],
#        [  1.00502513,   3.01507538],
#        [  2.01005025,   5.02512563],
#        [  3.01507538,   7.03517588],
#        [  4.0201005 ,   9.04522613],
#        [  5.02512563,  11.05527638],
#        [  6.03015075,  13.06532663],
#        [  7.03517588,  15.07537688],
#        [  8.04020101,  17.08542714],
#        [  9.04522613,  19.09547739],
#        [ 10.05025126,  21.10552764],
#        [ 11.05527638,  23.11557789],
#        [ 12.06030151,  25.12562814],
#        [ 13.06532663,  27.13567839],
#        [ 14.07035176,  29.14572864],
#        [ 15.07537688,  31.15577889],
#        [ 16.08040201,  33.16582915],
#        [ 17.08542714,  35.1758794 ],
#        [ 18.09045226,  37.18592965],
#        [ 19.09547739,  39.1959799 ],
#        [ 20.10050251,  41.20603015],
#        [ 21.10552764,  43.2160804 ],
#        [ 22.11055276,  45.22613065],
#        [ 23.11557789,  47.2361809 ],
#        [ 24.12060302,  49.24623116],
# ...

# %%
df_x = pd.DataFrame(f_x)
df_x
# Out:
#             0           1
# 0    0.000000    1.005025
# 1    1.005025    3.015075
# 2    2.010050    5.025126
# 3    3.015075    7.035176
# 4    4.020101    9.045226
# ..        ...         ...
# 95  95.477387  191.959799
# 96  96.482412  193.969849
# 97  97.487437  195.979899
# 98  98.492462  197.989950
# 99  99.497487  200.000000
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df_x[0],df_x[1])
plt.scatter(df['Площадь'],df['Этажи'])

# %%
# Out:
#             0           1
# 0    0.000000    1.005025
# 1    1.005025    3.015075
# 2    2.010050    5.025126
# 3    3.015075    7.035176
# 4    4.020101    9.045226
# ..        ...         ...
# 95  95.477387  191.959799
# 96  96.482412  193.969849
# 97  97.487437  195.979899
# 98  98.492462  197.989950
# 99  99.497487  200.000000
#
# [100 rows x 2 columns]
