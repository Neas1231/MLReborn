# %%
import pandas as pd
from numpy import absolute, mean, median
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from pyrolite.comp.codata import close
from pyrolite.plot import pyroplot
from pyrolite.plot.density import density
df = pd.read_csv("./data/vgsales.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe(include='object')
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df[df['Global_Sales'] == 0.01]
# Out:
#         Rank                                               Name Platform  \
# 15980  15983                                              Turok       PC
# 15981  15984                     Coven and Labyrinth of Refrain      PSV
# 15982  15985  Super Battle For Money Sentouchuu: Kyuukyoku n...      3DS
# 15983  15986                                   Dragon Zakura DS       DS
# 15984  15987                             Chameleon: To Dye For!       DS
# ...      ...                                                ...      ...
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year     Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 15980  2008.0    Action            Touchstone      0.00      0.01      0.00
# 15981  2016.0    Action  Nippon Ichi Software      0.00      0.00      0.01
# 15982  2016.0    Action    Namco Bandai Games      0.00      0.00      0.01
# 15983  2007.0      Misc       Electronic Arts      0.00      0.00      0.01
# 15984  2006.0    Puzzle             505 Games      0.01      0.00      0.00
# ...       ...       ...                   ...       ...       ...       ...
# 16593  2002.0  Platform                 Kemco      0.01      0.00      0.00
# 16594  2003.0   Shooter            Infogrames      0.01      0.00      0.00
# 16595  2008.0    Racing            Activision      0.00      0.00      0.00
# 16596  2010.0    Puzzle              7G//AMES      0.00      0.01      0.00
# 16597  2003.0  Platform               Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 15980          0.0          0.01
# 15981          0.0          0.01
# 15982          0.0          0.01
# 15983          0.0          0.01
# 15984          0.0          0.01
# ...            ...           ...
# 16593          0.0          0.01
# 16594          0.0          0.01
# 16595          0.0          0.01
# 16596          0.0          0.01
# 16597          0.0          0.01
#
# [618 rows x 11 columns]

# %%
dfc = df.copy()
dfc.dropna(inplace=True)

# %%
dfc.drop(columns=['Rank',],inplace=True)
dfc
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16291 rows x 10 columns]

# %%
years = dfc['Year']

# %% [markdown]
# # Среднее

# %%
# Среднее арифметическое
years.mean()
# Out:
# 2006.4055613528942

# %%
from scipy import stats
# Среднее усечённое
#calculate 10% trimmed mean
stats.trim_mean(years, 0.1)
# Out:
# 2006.8590501035833

# %%
# Медиана
years.median()
# Out:
# 2007.0

# %% [markdown]
# # Вариабельность

# %%
# Среднее абсолютное отклонение(mean absolute deviation)
# - years.mean(), берут в основном как среднее - медиану
def mad(data, axis=None):
    return mean(absolute(data - mean(data, axis)), axis)
mad(years)
# Out:
# 4.507306969675333

# %%
# Медианное абсолютное отклонение(median absolute deviation)
stats.median_abs_deviation(years)
# Out:
# 4.0

# %%
# Дисперсия(variance)
print(years.var())
def variance(data):
    return np.sum((data - mean(data))**2)/(len(data)-1)
variance(years)
# Out:
# 34.017032298429996
# 34.01703229843018

# %%
from statistics import variance
variance(years)
# Out:
# 34.01703229843019

# %%
# Стандартное отклонение(std)
years.var()**0.5
# Out:
# 5.8324122195220385

# %%
years.std()
# Out:
# 5.8324122195220385

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
plt.title('Mean')
plt.hist(years)
#std
plt.scatter(years.mean() + years.std(),3000,marker='>',color='b')
plt.scatter(years.mean() - years.std(),3000,marker='<',color='b')
#variance
plt.scatter(years.mean() - years.var(),3000,marker='<')
plt.scatter(years.mean() + years.var(),3000,marker='>')
# mean
plt.axvline(years.mean(),color='b')
# Expected value
plt.axvline(years.mean(),color='b')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Дисперсия показывает, насколько далеко распределены люди в группе \
# И наоборот, стандартное отклонение измеряет, насколько наблюдения набора данных отличаются от его среднего значения.

# %% [markdown]
# # Обследование распределения данных

# %%
# Перцентили
np.percentile(years,np.arange(10,100,10))
# Out:
# array([1998., 2002., 2004., 2006., 2007., 2009., 2010., 2011., 2013.])

# %%
# Квантили
np.quantile(years,np.arange(0.1,1,0.1))
# Out:
# array([1998., 2002., 2004., 2006., 2007., 2009., 2010., 2011., 2013.])

# %%
years.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # Графики

# %%
# Гистограммы
years.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.histplot(dfc['Year'].values)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # График плотности

# %%
years.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# plotting histogram and density  
# plot for carat using distplot() 
sns.histplot(dfc.Year, kde=True)
  
# visualizing plot using matplotlib.pyplot library 
plt.show()

# %% [markdown]
# # Двоичные и категориальные данные

# %%
# Столбчатые диаграммы
dfc.Platform.value_counts()
plt.figure(figsize=(15,7))
plt.bar(dfc.Platform.value_counts().index,dfc.Platform.value_counts().values)
# Out:
# <BarContainer object of 31 artists>

# %%
# Мода
years.mode()
# Out:
# 0    2009.0
# Name: Year, dtype: float64

# %%
# Мат ожидание (expected value)
sum(list(years.value_counts().index) * (years.value_counts()/len(years)))
''' 
В осномном мат ожидание == среднему арифметическому, но когда мы хотим посчитать ожидаемое среднее при определённых процентах
не имея при этом данных на руках мы можем только по выдуманным процентам посчитать среднее ожидаемое, оно же среднее взвешенное по вероятностям
'''
# Out:
# 2006.405561352894

# %%
# Круговые диаграммы(pie charts)
plt.pie(years.value_counts(),labels = list(map(int,list(years.value_counts().index))))
# Out:
# ([<matplotlib.patches.Wedge at 0x13e20027e10>,
#   <matplotlib.patches.Wedge at 0x13e20103090>,
#   <matplotlib.patches.Wedge at 0x13e201107d0>,
#   <matplotlib.patches.Wedge at 0x13e20112350>,
#   <matplotlib.patches.Wedge at 0x13e20113b10>,
#   <matplotlib.patches.Wedge at 0x13e20119850>,
#   <matplotlib.patches.Wedge at 0x13e2011ad10>,
#   <matplotlib.patches.Wedge at 0x13e2011c6d0>,
#   <matplotlib.patches.Wedge at 0x13e1fe1c210>,
#   <matplotlib.patches.Wedge at 0x13e20119590>,
#   <matplotlib.patches.Wedge at 0x13e20124c10>,
#   <matplotlib.patches.Wedge at 0x13e20126710>,
#   <matplotlib.patches.Wedge at 0x13e20127890>,
#   <matplotlib.patches.Wedge at 0x13e201314d0>,
#   <matplotlib.patches.Wedge at 0x13e20132e10>,
#   <matplotlib.patches.Wedge at 0x13e20138990>,
#   <matplotlib.patches.Wedge at 0x13e2013a1d0>,
#   <matplotlib.patches.Wedge at 0x13e2013bd50>,
#   <matplotlib.patches.Wedge at 0x13e20141550>,
#   <matplotlib.patches.Wedge at 0x13e20142d50>,
#   <matplotlib.patches.Wedge at 0x13e2014c5d0>,
#   <matplotlib.patches.Wedge at 0x13e2014dd50>,
#   <matplotlib.patches.Wedge at 0x13e2014f610>,
#   <matplotlib.patches.Wedge at 0x13e20037250>,
#   <matplotlib.patches.Wedge at 0x13e20152990>,
#   <matplotlib.patches.Wedge at 0x13e20158150>,
#   <matplotlib.patches.Wedge at 0x13e201598d0>,
#   <matplotlib.patches.Wedge at 0x13e2015b350>,
#   <matplotlib.patches.Wedge at 0x13e20160c50>,
#   <matplotlib.patches.Wedge at 0x13e20162650>,
#   <matplotlib.patches.Wedge at 0x13e20168050>,
#   <matplotlib.patches.Wedge at 0x13e20169910>,
#   <matplotlib.patches.Wedge at 0x13e2016b210>,
#   <matplotlib.patches.Wedge at 0x13e20170990>,
#   <matplotlib.patches.Wedge at 0x13e20172410>,
#   <matplotlib.patches.Wedge at 0x13e20173e10>,
#   <matplotlib.patches.Wedge at 0x13e20179690>,
#   <matplotlib.patches.Wedge at 0x13e2017b150>,
#   <matplotlib.patches.Wedge at 0x13e20180ad0>],
#  [Text(1.058381311499255, 0.2997148636105941, '2009'),
#   Text(0.7445578563538295, 0.8097120466818993, '2008'),
#   Text(0.24619095090106694, 1.0720960851035828, '2010'),
#   Text(-0.2703153843397028, 1.0662690059217135, '2007'),
#   Text(-0.7077612342316867, 0.8420653391031124, '2011'),
#   Text(-0.9864446545768559, 0.48675141854620996, '2006'),
#   Text(-1.0961674251538196, 0.09174407900047561, '2005'),
#   Text(-1.063910065026676, -0.27945549473025993, '2002'),
#   Text(-0.9283490505341179, -0.5900576585151674, '2003'),
#   Text(-0.7184211377380421, -0.8329892369359748, '2004'),
#   Text(-0.47042149518747445, -0.9943357666631434, '2012'),
#   Text(-0.21549653109298292, -1.0786849609996847, '2015'),
#   Text(0.03637302096634537, -1.0993984734143403, '2014'),
#   Text(0.27237110591052016, -1.0657457392197636, '2013'),
#   Text(0.47693077559907754, -0.9912300617346422, '2001'),
#   Text(0.6341976254581287, -0.8987732594282449, '1998'),
#   Text(0.7537220836490919, -0.8011885050471402, '2000'),
#   Text(0.8534860819435454, -0.6939463292853821, '2016'),
#   Text(0.9368968963026633, -0.5763889361346528, '1999'),
#   Text(0.9995793386586963, -0.45917441754375166, '1997'),
#   Text(1.0427077394694548, -0.3503720451898234, '1996'),
#   Text(1.070726833417391, -0.252079448190381, '1995'),
#   Text(1.0849422500398267, -0.18138443725556638, '1994'),
#   Text(1.090611250871126, -0.1434123407288161, '1993'),
#   Text(1.0933147322540135, -0.12109044651141845, '1981'),
#   Text(1.095231877117079, -0.10230901889178468, '1992'),
#   Text(1.096745391542193, -0.08455498879996469, '1991'),
#   Text(1.097879982257722, -0.06826085670268102, '1982'),
#   Text(1.0985639663820526, -0.05618907159700028, '1986'),
#   Text(1.098946220354129, -0.048137353161286554, '1989'),
#   Text(1.0992382157075447, -0.0409309800529339, '1983'),
#   Text(1.099476431927058, -0.03393487346294046, '1990'),
#   Text(1.099664906731826, -0.027149454920577687, '1987'),
#   Text(1.0998075584299314, -0.020575092232922948, '1988'),
#   Text(1.0999054241688837, -0.014424211724318984, '1985'),
#   Text(1.099967274407903, -0.008485000391813897, '1984'),
#   Text(1.0999940888658604, -0.003606169736138519, '1980'),
#   Text(1.099999488637726, -0.0010606586357674642, '2017'),
#   Text(1.099999979541411, -0.0002121530002801949, '2020')])

# %% [markdown]
# # Корреляция

# %%
dfc.dtypes
# Out:
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
dfc.select_dtypes(np.number)
# Out:
#          Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      2006.0     41.49     29.02      3.77         8.46         82.74
# 1      1985.0     29.08      3.58      6.81         0.77         40.24
# 2      2008.0     15.85     12.88      3.79         3.31         35.82
# 3      2009.0     15.75     11.01      3.28         2.96         33.00
# 4      1996.0     11.27      8.89     10.22         1.00         31.37
# ...       ...       ...       ...       ...          ...           ...
# 16593  2002.0      0.01      0.00      0.00         0.00          0.01
# 16594  2003.0      0.01      0.00      0.00         0.00          0.01
# 16595  2008.0      0.00      0.00      0.00         0.00          0.01
# 16596  2010.0      0.00      0.01      0.00         0.00          0.01
# 16597  2003.0      0.01      0.00      0.00         0.00          0.01
#
# [16291 rows x 6 columns]

# %%
# Корреляционная матрица
dfc.select_dtypes(np.number).corr(method='pearson', min_periods=1, numeric_only=False)
# Out:
#                   Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year          1.000000 -0.091285  0.006108 -0.169387     0.041128
# NA_Sales     -0.091285  1.000000  0.768923  0.451283     0.634518
# EU_Sales      0.006108  0.768923  1.000000  0.436379     0.726256
# JP_Sales     -0.169387  0.451283  0.436379  1.000000     0.290559
# Other_Sales   0.041128  0.634518  0.726256  0.290559     1.000000
# Global_Sales -0.074647  0.941269  0.903264  0.612774     0.747964
#
#               Global_Sales
# Year             -0.074647
# NA_Sales          0.941269
# EU_Sales          0.903264
# JP_Sales          0.612774
# Other_Sales       0.747964
# Global_Sales      1.000000

# %%
sns.heatmap(dfc.select_dtypes(np.number).corr(),annot=True,cbar=False)
# Out:
# <Axes: >

# %%
# Диаграмма рассеяния scatterplot
plt.scatter(dfc.Other_Sales,dfc.Global_Sales)
plt.xlabel("Other_Sales")
plt.ylabel("Global_Sales")
# Out:
# Text(0, 0.5, 'Global_Sales')

# %% [markdown]
# # Исследование двух или более переменных

# %%
# Графики с шестиугольной сеткой (hexagonal binning)
# Для норм графика нужно много сопряжённых данных
dfc.plot.hexbin(x='Other_Sales', y='Global_Sales', gridsize=30, )
# Out:
# <Axes: xlabel='Other_Sales', ylabel='Global_Sales'>

# %%
# Тут практически scatter но где цветастность - год
dfc.plot.hexbin(x='Other_Sales', y='Global_Sales',C='Year', gridsize=30, )
# Out:
# <Axes: xlabel='Other_Sales', ylabel='Global_Sales'>

# %%
# Плотность данных продаж по годам
fig = sns.jointplot(x = dfc.Global_Sales,y = dfc.Year, kind ="hex",height=6, ratio=5, space=0.1,)
#jointplot интересная штука, много показывает и вариабельность большая графиков

# %% [markdown]
# ### New datasets

# %%
scr_df = pd.read_csv("./data/scrabble_games.csv")
scr_df
# Out:
#           gameid  tourneyid    tie  winnerid           winnername  \
# 0              1          1  False       268  Harriette Lakernick
# 1              2          1  False       268  Harriette Lakernick
# 2              3          1  False       268  Harriette Lakernick
# 3              4          1  False       268  Harriette Lakernick
# 4              5          1  False       268  Harriette Lakernick
# ...          ...        ...    ...       ...                  ...
# 1542637  1823779       3021  False     15830     Ella Bartholomew
# 1542638  1823780       3021  False      1859        Claire Ullman
# 1542639  1823781       3021  False      2750       Poppy Thompson
# 1542640  1823782       3021  False      2750       Poppy Thompson
# 1542641  1823783       3021  False      2750       Poppy Thompson
#
#          winnerscore  winneroldrating  winnernewrating  winnerpos  loserid  \
# 0                  0             1568             1684          1      429
# 1                  0             1568             1684          1      435
# 2                  0             1568             1684          1      441
# 3                  0             1568             1684          1      456
# 4                  0             1568             1684          1     1334
# ...              ...              ...              ...        ...      ...
# 1542637            0                0              923         21     2750
# 1542638            0              730              756         23     2750
# 1542639            0                0              771         30     6345
# 1542640            0                0              771         30     2441
# 1542641            0                0              771         30     4226
#
#                 losername  loserscore  loseroldrating  losernewrating  \
# 0        Patricia Barrett           0            1915            1872
# 1              Chris Cree           0            1840            1798
# 2        Caesar Jaramillo           0            1622            1606
# 3           Mike Chitwood           0            1612            1600
# 4             Nancy Scott           0            1537            1590
# ...                   ...         ...             ...             ...
# 1542637    Poppy Thompson           0               0             771
# 1542638    Poppy Thompson           0               0             771
# 1542639        Myra Odess           0            1150            1111
# 1542640       Avis Turner           0             739             724
# 1542641     Lois Molitors           0               0             510
#
#          loserpos  round  division        date  lexicon
# 0               3      1         1  1998-12-06    False
# 1               6      2         1  1998-12-06    False
# 2              10      3         1  1998-12-06    False
# 3               9      4         1  1998-12-06    False
# 4               4      6         1  1998-12-06    False
# ...           ...    ...       ...         ...      ...
# 1542637        30      6         3  1994-09-17    False
# 1542638        30      8         3  1994-09-17    False
# 1542639        16      2         3  1994-09-17    False
# 1542640        27      3         3  1994-09-17    False
# 1542641        32     11         3  1994-09-17    False
#
# [1542642 rows x 19 columns]

# %%
sample = scr_df[(scr_df.losernewrating > 0) & (scr_df.winnernewrating > 0)]
plt.scatter(sample.winnernewrating,sample.losernewrating)

# %%
sample.plot.hexbin(x="winnernewrating",y="losernewrating", gridsize=40)
# Out:
# <Axes: xlabel='winnernewrating', ylabel='losernewrating'>

# %%
from pyrolite.comp.codata import close
from pyrolite.plot import pyroplot
from pyrolite.plot.density import density
# Контурные графики (contour plots)
sample = scr_df.loc[(scr_df.losernewrating > 0) & (scr_df.winnernewrating > 0), ["winnernewrating","losernewrating"]]
ax = sample.plot.hexbin(x="winnernewrating",y="losernewrating", gridsize=40,cmap='magma')
sample.pyroplot.density(ax=ax, contours=[0.95, 0.66, 0.33],cmap="tab10")
# Out:
# <Axes: xlabel='winnernewrating', ylabel='losernewrating'>

# %%
sample = scr_df.loc[(scr_df.losernewrating > 0) & (scr_df.winnernewrating > 0), ["winnernewrating","losernewrating"]]
ax = sample.pyroplot.scatter(ax=ax, s=10, alpha=0.3, c="#ABD5D7", zorder=2)
sample.pyroplot.density(ax=ax, contours=[0.95, 0.66, 0.33],cmap="tab10")
plt.show()

# %%
fifa_df = pd.read_csv("./data/players_20.csv")
fifa_df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0                       FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 1                           Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3
# 2                Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 3                    Atlético Madrid  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4                        Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# 18273               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2  43+2  45+2
# 18274               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2  44+2  46+2
# 18275         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2  47+2  47+2
# 18276  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2  48+2  48+2
# 18277         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2  48+2  48+2
#
#         lcb    cb   rcb    rb
# 0      52+2  52+2  52+2  63+2
# 1      53+3  53+3  53+3  61+3
# 2      46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN
# 4      49+3  49+3  49+3  61+3
# ...     ...   ...   ...   ...
# 18273  46+2  46+2  46+2  45+2
# 18274  47+2  47+2  47+2  46+2
# 18275  49+2  49+2  49+2  47+2
# 18276  49+2  49+2  49+2  48+2
# 18277  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %%
sample = fifa_df
plt.scatter(sample.height_cm,sample.weight_kg)

# %%
sample.plot.hexbin(x="height_cm",y="weight_kg", gridsize=40)
# Out:
# <Axes: xlabel='height_cm', ylabel='weight_kg'>

# %%
# Выполняется долго, мучался пока подбирал датасет
ax = sns.kdeplot(x = sample.height_cm,y=sample.weight_kg)
ax.scatter(sample.height_cm,sample.weight_kg,c='#ABD5D7')

# %%
# !pip install pyrolite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyrolite
#   Downloading pyrolite-0.3.5.post0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in c:\users\nicka\appdata\roaming\python\python311\site-packages (from pyrolite) (1.24.4)
# Requirement already satisfied: numpydoc in d:\hran\anacondaz\lib\site-packages (from pyrolite) (1.5.0)
# Collecting tinydb>4.1 (from pyrolite)
#   Downloading tinydb-4.8.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting periodictable (from pyrolite)
#   Downloading periodictable-1.7.1.tar.gz (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---- ----------------------------------- 0.1/1.0 MB 2.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.5/1.0 MB 4.7 MB/s eta 0:00:01
#      --------------------------------- ------ 0.8/1.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in d:\hran\anacondaz\lib\site-packages (from pyrolite) (3.8.0)
# Collecting mpltern>=0.4.0 (from pyrolite)
#   Downloading mpltern-1.0.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: scipy>=1.2 in c:\users\nicka\appdata\roaming\python\python311\site-packages (from pyrolite) (1.10.1)
# Requirement already satisfied: sympy>=1.7 in d:\hran\anacondaz\lib\site-packages (from pyrolite) (1.12)
# Requirement already satisfied: pandas>=1.0 in c:\users\nicka\appdata\roaming\python\python311\site-packages (from pyrolite) (1.5.3)
# Requirement already satisfied: requests in d:\hran\anacondaz\lib\site-packages (from pyrolite) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\hran\anacondaz\lib\site-packages (from matplotlib->pyrolite) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\hran\anacondaz\lib\site-packages (from pandas>=1.0->pyrolite) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in d:\hran\anacondaz\lib\site-packages (from sympy>=1.7->pyrolite) (1.3.0)
# Requirement already satisfied: sphinx>=4.2 in d:\hran\anacondaz\lib\site-packages (from numpydoc->pyrolite) (5.0.2)
# Requirement already satisfied: Jinja2>=2.10 in d:\hran\anacondaz\lib\site-packages (from numpydoc->pyrolite) (3.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\hran\anacondaz\lib\site-packages (from requests->pyrolite) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\hran\anacondaz\lib\site-packages (from requests->pyrolite) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\hran\anacondaz\lib\site-packages (from requests->pyrolite) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\hran\anacondaz\lib\site-packages (from requests->pyrolite) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\hran\anacondaz\lib\site-packages (from Jinja2>=2.10->numpydoc->pyrolite) (2.1.3)
# Requirement already satisfied: six>=1.5 in d:\hran\anacondaz\lib\site-packages (from python-dateutil>=2.7->matplotlib->pyrolite) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (2.15.1)
# Requirement already satisfied: docutils<0.19,>=0.14 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (0.18.1)
# Requirement already satisfied: snowballstemmer>=1.1 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (2.2.0)
# Requirement already satisfied: babel>=1.3 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (0.7.12)
# Requirement already satisfied: imagesize in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (1.4.1)
# Requirement already satisfied: colorama>=0.3.5 in d:\hran\anacondaz\lib\site-packages (from sphinx>=4.2->numpydoc->pyrolite) (0.4.6)
# Downloading pyrolite-0.3.5.post0-py3-none-any.whl (880 kB)
#    ---------------------------------------- 0.0/880.1 kB ? eta -:--:--
#    ----------------- --------------------- 389.1/880.1 kB 12.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 778.2/880.1 kB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 880.1/880.1 kB 8.0 MB/s eta 0:00:00
# Downloading mpltern-1.0.4-py3-none-any.whl (32 kB)
# Downloading tinydb-4.8.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: periodictable
#   Building wheel for periodictable (setup.py): started
#   Building wheel for periodictable (setup.py): finished with status 'done'
#   Created wheel for periodictable: filename=periodictable-1.7.1-py3-none-any.whl size=752532 sha256=9571b52cf2314345c3398415c70b9da9b887c4b564da7ea708a434ce3a8099c8
#   Stored in directory: c:\users\nicka\appdata\local\pip\cache\wheels\10\eb\8c\4cf77ee5d12487828b230d3021aa01643f07e3a1ed379859a2
# Successfully built periodictable
# Installing collected packages: tinydb, periodictable, mpltern, pyrolite
# Successfully installed mpltern-1.0.4 periodictable-1.7.1 pyrolite-0.3.5.post0 tinydb-4.8.0
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyrolite.comp.codata import close
from pyrolite.plot import pyroplot
from pyrolite.plot.density import density
ax = fifa_df.loc[:, ["height_cm","weight_kg"]].pyroplot.scatter(s=10, alpha=0.3, c="#ABD5D7", zorder=2)
fifa_df.loc[:, ["height_cm","weight_kg"]].pyroplot.density(ax=ax, contours=[0.95, 0.66, 0.33],cmap="tab10")
plt.show()

# %%
np.arange(1,0,-0.3)
# Out:
# array([1. , 0.7, 0.4, 0.1])

# %%
ax = fifa_df.loc[:, ["height_cm","weight_kg"]].pyroplot.scatter(s=10, alpha=0.3, c="#ABD5D7", zorder=2)
fifa_df.loc[:, ["height_cm","weight_kg"]].pyroplot.density(ax=ax, contours=list(np.arange(1,0,-0.1)),cmap="tab10",label_contours=False)
plt.show()

# %%
fig = plt.figure() 
ax = fig.add_axes([0, 0, 1.2, 1.2],) 
fifa_df.loc[:, ["height_cm","weight_kg"]].pyroplot.density(ax = ax,colorbar=True)
# Out:
# <Axes: xlabel='height_cm', ylabel='weight_kg'>

# %% [markdown]
# # Matplotlib colours
# https://matplotlib.org/stable/users/explain/colors/colors.html

# %%
from matplotlib import colormaps
import matplotlib
print(*list(colormaps),sep='\n')
# Out:
# magma
# inferno
# plasma
# viridis
# cividis
# twilight
# twilight_shifted
# turbo
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Spectral
# Wistia
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spring
# summer
# terrain
# winter
# Accent
# Dark2
# Paired
# Pastel1
# Pastel2
# Set1
# Set2
# Set3
# tab10
# tab20
# tab20b
# tab20c
# grey
# gist_grey
# gist_yerg
# Grays
# magma_r
# inferno_r
# plasma_r
# viridis_r
# cividis_r
# twilight_r
# twilight_shifted_r
# turbo_r
# Blues_r
# BrBG_r
# BuGn_r
# BuPu_r
# CMRmap_r
# GnBu_r
# Greens_r
# Greys_r
# OrRd_r
# Oranges_r
# PRGn_r
# PiYG_r
# PuBu_r
# PuBuGn_r
# PuOr_r
# PuRd_r
# Purples_r
# RdBu_r
# RdGy_r
# RdPu_r
# RdYlBu_r
# RdYlGn_r
# Reds_r
# Spectral_r
# Wistia_r
# YlGn_r
# YlGnBu_r
# YlOrBr_r
# YlOrRd_r
# afmhot_r
# autumn_r
# binary_r
# bone_r
# brg_r
# bwr_r
# cool_r
# coolwarm_r
# copper_r
# cubehelix_r
# flag_r
# gist_earth_r
# gist_gray_r
# gist_heat_r
# gist_ncar_r
# gist_rainbow_r
# gist_stern_r
# gist_yarg_r
# gnuplot_r
# gnuplot2_r
# gray_r
# hot_r
# hsv_r
# jet_r
# nipy_spectral_r
# ocean_r
# pink_r
# prism_r
# rainbow_r
# seismic_r
# spring_r
# summer_r
# terrain_r
# winter_r
# Accent_r
# Dark2_r
# Paired_r
# Pastel1_r
# Pastel2_r
# Set1_r
# Set2_r
# Set3_r
# tab10_r
# tab20_r
# tab20b_r
# tab20c_r
# rocket
# rocket_r
# mako
# mako_r
# icefire
# icefire_r
# vlag
# vlag_r
# flare
# flare_r
# crest
# crest_r
